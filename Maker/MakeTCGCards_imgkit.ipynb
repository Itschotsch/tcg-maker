# %%
# This Notebook renders a set of cards for a TCG game.
# The layout of a card is defined in ./card.html.
# The data for the cards is defined in ./cards.csv.
# This notebook loads the CSV file, replaces the placeholders in the HTML file and renders the cards as PNG images into ./singles/[ID]_[NAME].png
# It then stitches the cards together into a single PNG image and saves it to ./cards.png.

# %%
# Imports
# %pip install imgkit pandas
import pandas as pd
import imgkit
import re
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: imgkit in c:\python311\lib\site-packages (1.2.3)
# Requirement already satisfied: pandas in c:\python311\lib\site-packages (2.1.1)
# Requirement already satisfied: six in c:\python311\lib\site-packages (from imgkit) (1.16.0)
# Requirement already satisfied: numpy>=1.23.2 in c:\python311\lib\site-packages (from pandas) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python311\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python311\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\python311\lib\site-packages (from pandas) (2023.3)

# %%
# Load the CSV file, keep "" as empty string, not NaN
df = pd.read_csv('cards.csv', keep_default_na=False)

# Load the HTML template
html_template = ""
with open('card.html', 'r', encoding='utf-8') as f:
    html_template = f.read()

# %%
df.head()
# Out:
#    ID EntityType                  Title  \
# 0   0  Charakter  Schildheilerin Elaria
# 1   1  Charakter    Speerfischer Albert
# 2   2  Charakter      Speerfischer Hans
# 3   3  Charakter       Netzfischer Alto
# 4   4  Charakter           Schleimkröte
#
#                                          Description                   Cost  \
# 0  Wenn eine Deiner Charaktern, inklusive Schildh...                Aqua, 4
# 1                                                                   Aqua, 2
# 2                                                                   Aqua, 2
# 3  Wenn der Netzfischer Alto eine Konstante zerst...                Aqua, 3
# 4  Wenn die Schleimkröte ein Ziel angreift, darfs...  Aqua, 4 oder Terra, 4
#
#                                              Artwork OffensiveStat  \
# 0  https://cdn.discordapp.com/attachments/1140326...            15
# 1  Starterdeck%20Aqua%206b2d4d985fa943b5bb176dca7...            30
# 2  https://cdn.discordapp.com/attachments/1140326...            20
# 3  https://cdn.discordapp.com/attachments/1140326...            20
# 4  https://cdn.discordapp.com/attachments/1140326...            30
#
#   DefensiveStat Faction  TODOType FlavourText MetaExplanation  \
# 0            15            Heiler                  Draw, Buff
# 1            20           Gefolge
# 2            30           Gefolge
# 3            30           Gefolge
# 4            20          Wildtier
#
#                                  Decks    Status    Creator
# 0                     Starterdeck Aqua  Untested  Jan Appel
# 1                     Starterdeck Aqua  Untested  Jan Appel
# 2                     Starterdeck Aqua  Untested  Jan Appel
# 3                     Starterdeck Aqua  Untested  Jan Appel
# 4  Starterdeck Aqua, Starterdeck Terra  Untested  Jan Appel

# %%
print(html_template)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <!-- A card measures 63mm x 88mm -->
#     <meta name="viewport" content="width=§Width§, height=§Height§, initial-scale=1.0">
#     <title>§Title§</title>
#
#     <style>
#         html,
#         body {
#             margin: 0;
#             padding: 0;
#             width: 100%;
#             height: 100%;
#             display: flex;
#
#             font-family: "Linux Libertine", serif;
#         }
#
#         .card {
#             display: flex;
#             flex-direction: column;
#             justify-content: space-between;
#             align-items: center;
#
#             width: 100%;
#             height: 100%;
#             padding: §Bleed§;
#
#             background-color: brown;
#             color: white;
#         }
#
#         .title {
#             display: flex;
#             justify-content: center;
#             align-items: center;
#
#             font-size: 3rem;
#
#             padding: 1rem;
#         }
#
#         .description {
#             display: flex;
#             justify-content: center;
#             align-items: center;
#
#             font-size: 1.5rem;
#
#             padding: 1rem;
#         }
#     </style>
# </head>
#
# <body>
#     <div class="card">
#         <div class="title">§Title§</div>
#         <div class="description">
#             §Description§
#             Unicode u with umlaut: ü
#             Unicode chinese character: 丂
#         </div>
#     </div>
# </body>
#
# </html>

# %%
width_mm = 63
height_mm = 88
bleed_mm = 3
dpi = 300
width_px = int((width_mm + 2 * bleed_mm) * dpi / 25.4)
height_px = int((height_mm + 2 * bleed_mm) * dpi / 25.4)
bleed_px = int(bleed_mm * dpi / 25.4)

# Render the cards
for index, row in df.iterrows():
    print(f"Rendering card {row['Title']}...")

    # Copy the string html_template to template so the original template is not modified
    template = html_template
    
    # Replace width, height and bleed
    template = template.replace("§Width§", str(width_px))
    template = template.replace("§Height§", str(height_px))
    template = template.replace("§Bleed§", str(bleed_px / width_px * 100) + "%")

    # Find all {{Placeholder}}s in the HTML template
    placeholders = re.findall(r"§(.*?)§", template)

    # Replace the placeholders in the HTML template
    for placeholder in placeholders:
        template = template.replace(f"§{placeholder}§", str(row[placeholder]))
    
    print(template)

    # Render the HTML template as a PNG image
    imgkit.from_string(
        template,
        f'singles/{row["ID"]}_{row["Title"]}.png',
        options={
            'width': width_px,
            'height': height_px,
            'encoding': 'UTF-8'
        }
    )
# Out:
# Rendering card Schildheilerin Elaria...
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <!-- A card measures 63mm x 88mm -->
#     <meta name="viewport" content="width=814, height=1110, initial-scale=1.0">
#     <title>§Title§</title>
#
#     <style>
#         html,
#         body {
#             margin: 0;
#             padding: 0;
#             width: 100%;
#             height: 100%;
#             display: flex;
#
#             font-family: "Linux Libertine", serif;
#         }
#
#         .card {
#             display: flex;
#             flex-direction: column;
#             justify-content: space-between;
#             align-items: center;
#
#             width: 100%;
#             height: 100%;
#             padding: 4.2997542997543%;
#
#             background-color: brown;
#             color: white;
#         }
#
#         .title {
#             display: flex;
#             justify-content: center;
#             align-items: center;
#
#             font-size: 3rem;
#
#             padding: 1rem;
#         }
#
#         .description {
#             display: flex;
#             justify-content: center;
#             align-items: center;
#
#             font-size: 1.5rem;
#
#             padding: 1rem;
#         }
#     </style>
# </head>
#
# <body>
#     <div class="card">
#         <div class="title">§Title§</div>
#         <div class="description">
#             §Description§
#             Unicode u with umlaut: ü
#             Unicode chinese character: 丂
#         </div>
#     </div>
# </body>
#
# </html>
# Loading page (1/2)
# Rendering (2/2)
# Done
# Rendering card Speerfischer Albert...
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <!-- A card measures 63mm x 88mm -->
#     <meta name="viewport" content="width=814, height=1110, initial-scale=1.0">
#     <title>§Title§</title>
#
#     <style>
#         html,
#         body {
#             margin: 0;
#             padding: 0;
#             width: 100%;
#             height: 100%;
#             display: flex;
#
#             font-family: "Linux Libertine", serif;
#         }
#
#         .card {
#             display: flex;
#             flex-direction: column;
#             justify-content: space-between;
#             align-items: center;
#
#             width: 100%;
#             height: 100%;
#             padding: 4.2997542997543%;
#
#             background-color: brown;
#             color: white;
#         }
#
#         .title {
#             display: flex;
#             justify-content: center;
#             align-items: center;
#
#             font-size: 3rem;
#
#             padding: 1rem;
#         }
#
#         .description {
#             display: flex;
#             justify-content: center;
#             align-items: center;
#
#             font-size: 1.5rem;
#
#             padding: 1rem;
#         }
#     </style>
# </head>
#
# <body>
#     <div class="card">
#         <div class="title">§Title§</div>
#         <div class="description">
#             §Description§
#             Unicode u with umlaut: ü
#             Unicode chinese character: 丂
#         </div>
#     </div>
# </body>
#
# </html>
# Loading page (1/2)
# Rendering (2/2)
# Done
# Rendering card Speerfischer Hans...
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <!-- A card measures 63mm x 88mm -->
#     <meta name="viewport" content="width=814, height=1110, initial-scale=1.0">
#     <title>§Title§</title>
#
#     <style>
#         html,
#         body {
#             margin: 0;
#             padding: 0;
#             width: 100%;
#             height: 100%;
#             display: flex;
#
#             font-family: "Linux Libertine", serif;
#         }
#
#         .card {
#             display: flex;
#             flex-direction: column;
#             justify-content: space-between;
#             align-items: center;
#
#             width: 100%;
#             height: 100%;
#             padding: 4.2997542997543%;
#
#             background-color: brown;
#             color: white;
#         }
#
#         .title {
#             display: flex;
#             justify-content: center;
#             align-items: center;
#
#             font-size: 3rem;
#
#             padding: 1rem;
#         }
#
#         .description {
#             display: flex;
#             justify-content: center;
#             align-items: center;
#
#             font-size: 1.5rem;
#
#             padding: 1rem;
#         }
#     </style>
# </head>
#
# <body>
#     <div class="card">
#         <div class="title">§Title§</div>
#         <div class="description">
#             §Description§
#             Unicode u with umlaut: ü
#             Unicode chinese character: 丂
#         </div>
#     </div>
# </body>
#
# </html>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\jan\Documents\Personal\Projects\TCG\Maker\MakeTCGCards.ipynb Cell 6 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/jan/Documents/Personal/Projects/TCG/Maker/MakeTCGCards.ipynb#W4sZmlsZQ%3D%3D?line=27'>28</a> print(template)
#      <a href='vscode-notebook-cell:/c%3A/Users/jan/Documents/Personal/Projects/TCG/Maker/MakeTCGCards.ipynb#W4sZmlsZQ%3D%3D?line=29'>30</a> # Render the HTML template as a PNG image
# ---> <a href='vscode-notebook-cell:/c%3A/Users/jan/Documents/Personal/Projects/TCG/Maker/MakeTCGCards.ipynb#W4sZmlsZQ%3D%3D?line=30'>31</a> imgkit.from_string(
#      <a href='vscode-notebook-cell:/c%3A/Users/jan/Documents/Personal/Projects/TCG/Maker/MakeTCGCards.ipynb#W4sZmlsZQ%3D%3D?line=31'>32</a>     template,
#      <a href='vscode-notebook-cell:/c%3A/Users/jan/Documents/Personal/Projects/TCG/Maker/MakeTCGCards.ipynb#W4sZmlsZQ%3D%3D?line=32'>33</a>     f'singles/{row["ID"]}_{row["Title"]}.png',
#      <a href='vscode-notebook-cell:/c%3A/Users/jan/Documents/Personal/Projects/TCG/Maker/MakeTCGCards.ipynb#W4sZmlsZQ%3D%3D?line=33'>34</a>     options={
#      <a href='vscode-notebook-cell:/c%3A/Users/jan/Documents/Personal/Projects/TCG/Maker/MakeTCGCards.ipynb#W4sZmlsZQ%3D%3D?line=34'>35</a>         'width': width_px,
#      <a href='vscode-notebook-cell:/c%3A/Users/jan/Documents/Personal/Projects/TCG/Maker/MakeTCGCards.ipynb#W4sZmlsZQ%3D%3D?line=35'>36</a>         'height': height_px,
#      <a href='vscode-notebook-cell:/c%3A/Users/jan/Documents/Personal/Projects/TCG/Maker/MakeTCGCards.ipynb#W4sZmlsZQ%3D%3D?line=36'>37</a>         'encoding': 'UTF-8'
#      <a href='vscode-notebook-cell:/c%3A/Users/jan/Documents/Personal/Projects/TCG/Maker/MakeTCGCards.ipynb#W4sZmlsZQ%3D%3D?line=37'>38</a>     }
#      <a href='vscode-notebook-cell:/c%3A/Users/jan/Documents/Personal/Projects/TCG/Maker/MakeTCGCards.ipynb#W4sZmlsZQ%3D%3D?line=38'>39</a> )
#
# File c:\Python311\Lib\site-packages\imgkit\api.py:108, in from_string(string, output_path, options, toc, cover, css, config, cover_first)
#      85 """
#      86 Convert given string/strings to IMG file
#      87
#    (...)
#      96 :return: True when success
#      97 """
#      98 rtn = IMGKit(
#      99     string,
#     100     "string",
#    (...)
#     106     cover_first=cover_first,
#     107 )
# --> 108 return rtn.to_img(output_path)
#
# File c:\Python311\Lib\site-packages\imgkit\imgkit.py:240, in IMGKit.to_img(self, path)
#     238 else:
#     239     string = None
# --> 240 stdout, stderr = result.communicate(input=string)
#     241 stderr = stderr or stdout
#     242 try:
#
# File c:\Python311\Lib\subprocess.py:1205, in Popen.communicate(self, input, timeout)
#    1202     endtime = None
#    1204 try:
# -> 1205     stdout, stderr = self._communicate(input, endtime, timeout)
#    1206 except KeyboardInterrupt:
#    1207     # https://bugs.python.org/issue25942
#    1208     # See the detailed comment in .wait().
#    1209     if timeout is not None:
#
# File c:\Python311\Lib\subprocess.py:1579, in Popen._communicate(self, input, endtime, orig_timeout)
#    1575 # Wait for the reader threads, or time out.  If we time out, the
#    1576 # threads remain reading and the fds left open in case the user
#    1577 # calls communicate again.
#    1578 if self.stdout is not None:
# -> 1579     self.stdout_thread.join(self._remaining_time(endtime))
#    1580     if self.stdout_thread.is_alive():
#    1581         raise TimeoutExpired(self.args, orig_timeout)
#
# File c:\Python311\Lib\threading.py:1112, in Thread.join(self, timeout)
#    1109     raise RuntimeError("cannot join current thread")
#    1111 if timeout is None:
# -> 1112     self._wait_for_tstate_lock()
#    1113 else:
#    1114     # the behavior of a negative timeout isn't documented, but
#    1115     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1116     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File c:\Python311\Lib\threading.py:1132, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1129     return
#    1131 try:
# -> 1132     if lock.acquire(block, timeout):
#    1133         lock.release()
#    1134         self._stop()
#
# KeyboardInterrupt:
