# %%
# This Notebook renders a set of cards for a TCG game.
# The layout of a card is defined in ./card.html.
# The data for the cards is defined in ./cards.csv.
# This notebook loads the CSV file, replaces the placeholders in the HTML file and renders the cards as PNG images into ./singles/[ID]_[NAME].png
# It then stitches the cards together into a single PNG image and saves it to ./cards.png.

# %%
# Imports
# %pip install --upgrade pip
# %pip install pandas pytest-playwright
# %playwright install
import pandas as pd
import re
from playwright.async_api import async_playwright
# import nest_asyncio
# nest_asyncio.apply()

# %%
# Load the CSV file, keep "" as empty string, not NaN
df = pd.read_csv('cards.csv', keep_default_na=False)

# Load the HTML template
html_template = ""
with open('card.html', 'r', encoding='utf-8') as f:
    html_template = f.read()

# %%
df.head()
# Out:
#    ID EntityType                  Title  \
# 0   0  Charakter  Schildheilerin Elaria
# 1   1  Charakter    Speerfischer Albert
# 2   2  Charakter      Speerfischer Hans
# 3   3  Charakter       Netzfischer Alto
# 4   4  Charakter           Schleimkröte
#
#                                          Description                   Cost  \
# 0  Wenn eine Deiner Charaktern, inklusive Schildh...                Aqua, 4
# 1                                                                   Aqua, 2
# 2                                                                   Aqua, 2
# 3  Wenn der Netzfischer Alto eine Konstante zerst...                Aqua, 3
# 4  Wenn die Schleimkröte ein Ziel angreift, darfs...  Aqua, 4 oder Terra, 4
#
#                                              Artwork OffensiveStat  \
# 0  https://cdn.discordapp.com/attachments/1140326...            15
# 1  Starterdeck%20Aqua%206b2d4d985fa943b5bb176dca7...            30
# 2  https://cdn.discordapp.com/attachments/1140326...            20
# 3  https://cdn.discordapp.com/attachments/1140326...            20
# 4  https://cdn.discordapp.com/attachments/1140326...            30
#
#   DefensiveStat Faction  TODOType FlavourText MetaExplanation  \
# 0            15            Heiler                  Draw, Buff
# 1            20           Gefolge
# 2            30           Gefolge
# 3            30           Gefolge
# 4            20          Wildtier
#
#                                  Decks    Status    Creator
# 0                     Starterdeck Aqua  Untested  Jan Appel
# 1                     Starterdeck Aqua  Untested  Jan Appel
# 2                     Starterdeck Aqua  Untested  Jan Appel
# 3                     Starterdeck Aqua  Untested  Jan Appel
# 4  Starterdeck Aqua, Starterdeck Terra  Untested  Jan Appel

# %%
print(html_template)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <!-- A card measures 63mm x 88mm -->
#     <meta name="viewport" content="width=§Width§, height=§Height§, initial-scale=1.0">
#     <title>§Title§</title>
#
#     <style>
#         html,
#         body {
#             margin: 0;
#             padding: 0;
#             width: 100%;
#             height: 100%;
#             display: flex;
#
#             font-family: "Linux Libertine", serif;
#         }
#
#         .card {
#             display: flex;
#             flex-direction: column;
#             justify-content: space-between;
#             align-items: center;
#
#             width: 100%;
#             height: 100%;
#             padding: §Bleed§;
#
#             background-color: brown;
#             color: white;
#         }
#
#         .title {
#             display: flex;
#             justify-content: center;
#             align-items: center;
#
#             font-size: 3rem;
#
#             padding: 1rem;
#         }
#
#         .description {
#             display: flex;
#             justify-content: center;
#             align-items: center;
#
#             font-size: 1.5rem;
#
#             padding: 1rem;
#         }
#     </style>
# </head>
#
# <body>
#     <div class="card">
#         <div class="title">§Title§</div>
#         <div class="description">
#             §Description§
#             Unicode u with umlaut: ü
#             Unicode chinese character: 丂
#         </div>
#     </div>
# </body>
#
# </html>

# %%
width_mm = 63
height_mm = 88
bleed_mm = 3
dpi = 300
width_px = int((width_mm + 2 * bleed_mm) * dpi / 25.4)
height_px = int((height_mm + 2 * bleed_mm) * dpi / 25.4)
bleed_px = int(bleed_mm * dpi / 25.4)

# Render the cards
for index, row in df.iterrows():
    print(f"Rendering card {row['Title']}...")

    # Copy the string html_template to template so the original template is not modified
    template = html_template
    
    # Replace width, height and bleed
    template = template.replace("§Width§", str(width_px))
    template = template.replace("§Height§", str(height_px))
    template = template.replace("§Bleed§", str(bleed_px / width_px * 100) + "%")

    # Find all {{Placeholder}}s in the HTML template
    placeholders = re.findall(r"§(.*?)§", template)

    # Replace the placeholders in the HTML template
    for placeholder in placeholders:
        template = template.replace(f"§{placeholder}§", str(row[placeholder]))
    
    print(template)

    # Render the HTML template as a PNG image
    # with sync_playwright() as p:
    #     browser = p.chromium.launch()
    #     page = browser.new_page()
    #     page.set_content(template)
    #     page.screenshot(path=f"singles/{row['ID']}_{row['Title']}.png", full_page=True)
    #     print(f"Rendered {page.title()}")
    #     browser.close()
    # The above code is synchronous and doesn't work. Use the async API instead:
    async with async_playwright() as p:
        browser = await p.chromium.launch()
        page = await browser.new_page()
        await page.set_content(template)
        await page.screenshot(path=f"singles/{row['ID']}_{row['Title']}.png", full_page=True)
        print(f"Rendered {page.title()}")
        await browser.close()
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-6' coro=<Connection.run() done, defined at c:\Python311\Lib\site-packages\playwright\_impl\_connection.py:264> exception=NotImplementedError()>
# Traceback (most recent call last):
#   File "c:\Python311\Lib\site-packages\playwright\_impl\_connection.py", line 271, in run
#     await self._transport.connect()
#   File "c:\Python311\Lib\site-packages\playwright\_impl\_transport.py", line 135, in connect
#     raise exc
#   File "c:\Python311\Lib\site-packages\playwright\_impl\_transport.py", line 123, in connect
#     self._proc = await asyncio.create_subprocess_exec(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python311\Lib\asyncio\subprocess.py", line 218, in create_subprocess_exec
#     transport, protocol = await loop.subprocess_exec(
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python311\Lib\asyncio\base_events.py", line 1680, in subprocess_exec
#     transport = await self._make_subprocess_transport(
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python311\Lib\asyncio\base_events.py", line 502, in _make_subprocess_transport
#     raise NotImplementedError
# NotImplementedError
# Rendering card Schildheilerin Elaria...
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <!-- A card measures 63mm x 88mm -->
#     <meta name="viewport" content="width=814, height=1110, initial-scale=1.0">
#     <title>Schildheilerin Elaria</title>
#
#     <style>
#         html,
#         body {
#             margin: 0;
#             padding: 0;
#             width: 100%;
#             height: 100%;
#             display: flex;
#
#             font-family: "Linux Libertine", serif;
#         }
#
#         .card {
#             display: flex;
#             flex-direction: column;
#             justify-content: space-between;
#             align-items: center;
#
#             width: 100%;
#             height: 100%;
#             padding: 4.2997542997543%;
#
#             background-color: brown;
#             color: white;
#         }
#
#         .title {
#             display: flex;
#             justify-content: center;
#             align-items: center;
#
#             font-size: 3rem;
#
#             padding: 1rem;
#         }
#
#         .description {
#             display: flex;
#             justify-content: center;
#             align-items: center;
#
#             font-size: 1.5rem;
#
#             padding: 1rem;
#         }
#     </style>
# </head>
#
# <body>
#     <div class="card">
#         <div class="title">Schildheilerin Elaria</div>
#         <div class="description">
#             Wenn eine Deiner Charaktern, inklusive Schildheilerin Elaria, erscheint, entdecke einen Schild aus Deinem Deck. Du darfst die erschienene Konstante damit versehen. Andernfalls misches ihn inDein Deck.
#             Unicode u with umlaut: ü
#             Unicode chinese character: 丂
#         </div>
#     </div>
# </body>
#
# </html>
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# c:\Users\jan\Documents\Personal\Projects\TCG\Maker\MakeTCGCards_playwright.ipynb Cell 6 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/jan/Documents/Personal/Projects/TCG/Maker/MakeTCGCards_playwright.ipynb#W5sZmlsZQ%3D%3D?line=27'>28</a> print(template)
#      <a href='vscode-notebook-cell:/c%3A/Users/jan/Documents/Personal/Projects/TCG/Maker/MakeTCGCards_playwright.ipynb#W5sZmlsZQ%3D%3D?line=29'>30</a> # Render the HTML template as a PNG image
#      <a href='vscode-notebook-cell:/c%3A/Users/jan/Documents/Personal/Projects/TCG/Maker/MakeTCGCards_playwright.ipynb#W5sZmlsZQ%3D%3D?line=30'>31</a> # with sync_playwright() as p:
#      <a href='vscode-notebook-cell:/c%3A/Users/jan/Documents/Personal/Projects/TCG/Maker/MakeTCGCards_playwright.ipynb#W5sZmlsZQ%3D%3D?line=31'>32</a> #     browser = p.chromium.launch()
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/jan/Documents/Personal/Projects/TCG/Maker/MakeTCGCards_playwright.ipynb#W5sZmlsZQ%3D%3D?line=36'>37</a> #     browser.close()
#      <a href='vscode-notebook-cell:/c%3A/Users/jan/Documents/Personal/Projects/TCG/Maker/MakeTCGCards_playwright.ipynb#W5sZmlsZQ%3D%3D?line=37'>38</a> # The above code is synchronous and doesn't work. Use the async API instead:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/jan/Documents/Personal/Projects/TCG/Maker/MakeTCGCards_playwright.ipynb#W5sZmlsZQ%3D%3D?line=38'>39</a> async with async_playwright() as p:
#      <a href='vscode-notebook-cell:/c%3A/Users/jan/Documents/Personal/Projects/TCG/Maker/MakeTCGCards_playwright.ipynb#W5sZmlsZQ%3D%3D?line=39'>40</a>     browser = await p.chromium.launch()
#      <a href='vscode-notebook-cell:/c%3A/Users/jan/Documents/Personal/Projects/TCG/Maker/MakeTCGCards_playwright.ipynb#W5sZmlsZQ%3D%3D?line=40'>41</a>     page = await browser.new_page()
#
# File c:\Python311\Lib\site-packages\playwright\async_api\_context_manager.py:47, in PlaywrightContextManager.__aenter__(self)
#      45 if not playwright_future.done():
#      46     playwright_future.cancel()
# ---> 47 playwright = AsyncPlaywright(next(iter(done)).result())
#      48 playwright.stop = self.__aexit__  # type: ignore
#      49 return playwright
#
# File c:\Python311\Lib\site-packages\playwright\_impl\_transport.py:123, in PipeTransport.connect(self)
#     120         startupinfo.dwFlags |= subprocess.STARTF_USESHOWWINDOW
#     121         startupinfo.wShowWindow = subprocess.SW_HIDE
# --> 123     self._proc = await asyncio.create_subprocess_exec(
#     124         str(self._driver_executable),
#     125         "run-driver",
#     126         stdin=asyncio.subprocess.PIPE,
#     127         stdout=asyncio.subprocess.PIPE,
#     128         stderr=_get_stderr_fileno(),
#     129         limit=32768,
#     130         env=env,
#     131         startupinfo=startupinfo,
#     132     )
#     133 except Exception as exc:
#     134     self.on_error_future.set_exception(exc)
#
# File c:\Python311\Lib\asyncio\subprocess.py:218, in create_subprocess_exec(program, stdin, stdout, stderr, limit, *args, **kwds)
#     215 loop = events.get_running_loop()
#     216 protocol_factory = lambda: SubprocessStreamProtocol(limit=limit,
#     217                                                     loop=loop)
# --> 218 transport, protocol = await loop.subprocess_exec(
#     219     protocol_factory,
#     220     program, *args,
#     221     stdin=stdin, stdout=stdout,
#     222     stderr=stderr, **kwds)
#     223 return Process(transport, protocol, loop)
#
# File c:\Python311\Lib\asyncio\base_events.py:1680, in BaseEventLoop.subprocess_exec(self, protocol_factory, program, stdin, stdout, stderr, universal_newlines, shell, bufsize, encoding, errors, text, *args, **kwargs)
#    1678     debug_log = f'execute program {program!r}'
#    1679     self._log_subprocess(debug_log, stdin, stdout, stderr)
# -> 1680 transport = await self._make_subprocess_transport(
#    1681     protocol, popen_args, False, stdin, stdout, stderr,
#    1682     bufsize, **kwargs)
#    1683 if self._debug and debug_log is not None:
#    1684     logger.info('%s: %r', debug_log, transport)
#
# File c:\Python311\Lib\asyncio\base_events.py:502, in BaseEventLoop._make_subprocess_transport(self, protocol, args, shell, stdin, stdout, stderr, bufsize, extra, **kwargs)
#     498 async def _make_subprocess_transport(self, protocol, args, shell,
#     499                                      stdin, stdout, stderr, bufsize,
#     500                                      extra=None, **kwargs):
#     501     """Create subprocess transport."""
# --> 502     raise NotImplementedError
#
# NotImplementedError:

# %%
# in Jupyter
from playwright.async_api import async_playwright

pw = await async_playwright().start()
browser = await pw.chromium.launch(headless=False)
page = await browser.new_page()

# note all methods are async (use the "await" keyword)
await page.goto("http://scrapfly.io/")

# to stop browser on notebook close we can add a shutdown hook:
async def shutdown_playwright():
    await browser.close()
    await pw.stop()
import atexit
atexit.register(shutdown_playwright())
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-8' coro=<Connection.run() done, defined at c:\Python311\Lib\site-packages\playwright\_impl\_connection.py:264> exception=NotImplementedError()>
# Traceback (most recent call last):
#   File "c:\Python311\Lib\site-packages\playwright\_impl\_connection.py", line 271, in run
#     await self._transport.connect()
#   File "c:\Python311\Lib\site-packages\playwright\_impl\_transport.py", line 135, in connect
#     raise exc
#   File "c:\Python311\Lib\site-packages\playwright\_impl\_transport.py", line 123, in connect
#     self._proc = await asyncio.create_subprocess_exec(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python311\Lib\asyncio\subprocess.py", line 218, in create_subprocess_exec
#     transport, protocol = await loop.subprocess_exec(
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python311\Lib\asyncio\base_events.py", line 1680, in subprocess_exec
#     transport = await self._make_subprocess_transport(
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python311\Lib\asyncio\base_events.py", line 502, in _make_subprocess_transport
#     raise NotImplementedError
# NotImplementedError
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# c:\Users\jan\Documents\Personal\Projects\TCG\Maker\MakeTCGCards_playwright.ipynb Cell 7 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/jan/Documents/Personal/Projects/TCG/Maker/MakeTCGCards_playwright.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> # in Jupyter
#       <a href='vscode-notebook-cell:/c%3A/Users/jan/Documents/Personal/Projects/TCG/Maker/MakeTCGCards_playwright.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> from playwright.async_api import async_playwright
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jan/Documents/Personal/Projects/TCG/Maker/MakeTCGCards_playwright.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> pw = await async_playwright().start()
#       <a href='vscode-notebook-cell:/c%3A/Users/jan/Documents/Personal/Projects/TCG/Maker/MakeTCGCards_playwright.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> browser = await pw.chromium.launch(headless=False)
#       <a href='vscode-notebook-cell:/c%3A/Users/jan/Documents/Personal/Projects/TCG/Maker/MakeTCGCards_playwright.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a> page = await browser.new_page()
#
# File c:\Python311\Lib\site-packages\playwright\async_api\_context_manager.py:52, in PlaywrightContextManager.start(self)
#      51 async def start(self) -> AsyncPlaywright:
# ---> 52     return await self.__aenter__()
#
# File c:\Python311\Lib\site-packages\playwright\async_api\_context_manager.py:47, in PlaywrightContextManager.__aenter__(self)
#      45 if not playwright_future.done():
#      46     playwright_future.cancel()
# ---> 47 playwright = AsyncPlaywright(next(iter(done)).result())
#      48 playwright.stop = self.__aexit__  # type: ignore
#      49 return playwright
#
# File c:\Python311\Lib\site-packages\playwright\_impl\_transport.py:123, in PipeTransport.connect(self)
#     120         startupinfo.dwFlags |= subprocess.STARTF_USESHOWWINDOW
#     121         startupinfo.wShowWindow = subprocess.SW_HIDE
# --> 123     self._proc = await asyncio.create_subprocess_exec(
#     124         str(self._driver_executable),
#     125         "run-driver",
#     126         stdin=asyncio.subprocess.PIPE,
#     127         stdout=asyncio.subprocess.PIPE,
#     128         stderr=_get_stderr_fileno(),
#     129         limit=32768,
#     130         env=env,
#     131         startupinfo=startupinfo,
#     132     )
#     133 except Exception as exc:
#     134     self.on_error_future.set_exception(exc)
#
# File c:\Python311\Lib\asyncio\subprocess.py:218, in create_subprocess_exec(program, stdin, stdout, stderr, limit, *args, **kwds)
#     215 loop = events.get_running_loop()
#     216 protocol_factory = lambda: SubprocessStreamProtocol(limit=limit,
#     217                                                     loop=loop)
# --> 218 transport, protocol = await loop.subprocess_exec(
#     219     protocol_factory,
#     220     program, *args,
#     221     stdin=stdin, stdout=stdout,
#     222     stderr=stderr, **kwds)
#     223 return Process(transport, protocol, loop)
#
# File c:\Python311\Lib\asyncio\base_events.py:1680, in BaseEventLoop.subprocess_exec(self, protocol_factory, program, stdin, stdout, stderr, universal_newlines, shell, bufsize, encoding, errors, text, *args, **kwargs)
#    1678     debug_log = f'execute program {program!r}'
#    1679     self._log_subprocess(debug_log, stdin, stdout, stderr)
# -> 1680 transport = await self._make_subprocess_transport(
#    1681     protocol, popen_args, False, stdin, stdout, stderr,
#    1682     bufsize, **kwargs)
#    1683 if self._debug and debug_log is not None:
#    1684     logger.info('%s: %r', debug_log, transport)
#
# File c:\Python311\Lib\asyncio\base_events.py:502, in BaseEventLoop._make_subprocess_transport(self, protocol, args, shell, stdin, stdout, stderr, bufsize, extra, **kwargs)
#     498 async def _make_subprocess_transport(self, protocol, args, shell,
#     499                                      stdin, stdout, stderr, bufsize,
#     500                                      extra=None, **kwargs):
#     501     """Create subprocess transport."""
# --> 502     raise NotImplementedError
#
# NotImplementedError:
